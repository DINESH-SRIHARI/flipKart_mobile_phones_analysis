# %%
import numpy as n
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sea
import warnings 
warnings.filterwarnings('ignore')

# %%
fdf=p.read_csv(r'flipkart_data.csv',encoding='unicode_escape')

# %%
fdf.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0
#
#    Original Price
# 0         15990.0
# 1         15990.0
# 2         17990.0
# 3         17990.0
# 4         15990.0

# %%
fdf.shape
# Out:
# (2647, 8)

# %%
fdf.info()#information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2647 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2647 non-null   object
#  1   Model           2645 non-null   object
#  2   Color           2505 non-null   object
#  3   Memory          2605 non-null   object
#  4   Storage         2568 non-null   object
#  5   Rating          2647 non-null   float64
#  6   Selling Price   2644 non-null   float64
#  7   Original Price  969 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 165.6+ KB

# %%
fdf.isnull()#checking the null values
# Out:
#       Brand  Model  Color  Memory  Storage  Rating  Selling Price  \
# 0     False  False  False   False    False   False          False
# 1     False  False  False   False    False   False          False
# 2     False  False  False   False    False   False          False
# 3     False  False  False   False    False   False          False
# 4     False  False  False   False    False   False          False
# ...     ...    ...    ...     ...      ...     ...            ...
# 2642  False  False  False   False    False   False          False
# 2643  False  False  False   False    False   False          False
# 2644  False  False  False   False    False   False          False
# 2645  False  False  False   False    False   False          False
# 2646  False  False  False   False    False   False          False
#
#       Original Price
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# ...

# %%
p.isnull(fdf)
# Out:
#       Brand  Model  Color  Memory  Storage  Rating  Selling Price  \
# 0     False  False  False   False    False   False          False
# 1     False  False  False   False    False   False          False
# 2     False  False  False   False    False   False          False
# 3     False  False  False   False    False   False          False
# 4     False  False  False   False    False   False          False
# ...     ...    ...    ...     ...      ...     ...            ...
# 2642  False  False  False   False    False   False          False
# 2643  False  False  False   False    False   False          False
# 2644  False  False  False   False    False   False          False
# 2645  False  False  False   False    False   False          False
# 2646  False  False  False   False    False   False          False
#
#       Original Price
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# ...

# %%
p.isnull(fdf).sum()#checking how many values are null
# Out:
# Brand                0
# Model                2
# Color              142
# Memory              42
# Storage             79
# Rating               0
# Selling Price        3
# Original Price    1678
# dtype: int64

# %%
fdf['Original Price'].fillna(fdf['Selling Price'],inplace=True)

# %%
p.isnull(fdf).sum()
# Out:
# Brand               0
# Model               2
# Color             142
# Memory             42
# Storage            79
# Rating              0
# Selling Price       3
# Original Price      3
# dtype: int64

# %%
fdf.dropna(inplace=True)#dropping the null values rows

# %%
fdf.shape#checking number of rows and coloumns
# Out:
# (2436, 8)

# %%
fdf.isna().sum()
# Out:
# Brand             0
# Model             0
# Color             0
# Memory            0
# Storage           0
# Rating            0
# Selling Price     0
# Original Price    0
# dtype: int64

# %%
# finding the costiliest and cheapest phone
cheap=fdf.sort_values(['Selling Price']).iloc[0]
cheap
# Out:
# Brand             GIONEE
# Model              P5_W
# Color              Black
# Memory               1.0
# Storage            16 GB
# Rating               3.8
# Selling Price       2799
# Original Price      2799
# Name: 826, dtype: object

# %%
high_cost=fdf.sort_values(['Selling Price'],ascending=False).iloc[0]
high_cost
# Out:
# Brand                          Apple
# Model             iPhone 13 Pro Max
# Color                         Silver
# Memory                           6.0
# Storage                         1 TB
# Rating                           0.0
# Selling Price                 179900
# Original Price                179900
# Name: 1460, dtype: object

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2436 non-null   object
#  1   Model           2436 non-null   object
#  2   Color           2436 non-null   object
#  3   Memory          2436 non-null   object
#  4   Storage         2436 non-null   object
#  5   Rating          2436 non-null   float64
#  6   Selling Price   2436 non-null   float64
#  7   Original Price  2436 non-null   float64
# dtypes: float64(3), object(5)
# memory usage: 171.3+ KB

# %%
fdf['Selling Price']=fdf['Selling Price'].astype('int')
fdf['Original Price']=fdf['Original Price'].astype('int')

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2436 non-null   object
#  1   Model           2436 non-null   object
#  2   Color           2436 non-null   object
#  3   Memory          2436 non-null   object
#  4   Storage         2436 non-null   object
#  5   Rating          2436 non-null   float64
#  6   Selling Price   2436 non-null   int32
#  7   Original Price  2436 non-null   int32
# dtypes: float64(1), int32(2), object(5)
# memory usage: 152.2+ KB

# %%
fdf['Original Price'].dtypes
# Out:
# dtype('int32')

# %%
fdf.describe()
# Out:
#             Rating  Selling Price  Original Price
# count  2436.000000    2436.000000     2436.000000
# mean      4.039532   27297.366174    29382.552956
# std       0.935027   29143.243048    30922.295767
# min       0.000000    2290.000000     2290.000000
# 25%       4.000000    9999.000000    10999.000000
# 50%       4.300000   15990.000000    16999.000000
# 75%       4.400000   30922.500000    34900.000000
# max       5.000000  179900.000000   189999.000000

# %%
value = fdf.loc[fdf['Rating'] != 0, 'Rating'].mean()
value=int(value)

# %%
value
# Out:
# 4

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2436 non-null   object
#  1   Model           2436 non-null   object
#  2   Color           2436 non-null   object
#  3   Memory          2436 non-null   object
#  4   Storage         2436 non-null   object
#  5   Rating          2436 non-null   float64
#  6   Selling Price   2436 non-null   int32
#  7   Original Price  2436 non-null   int32
# dtypes: float64(1), int32(2), object(5)
# memory usage: 152.2+ KB

# %%
 fdf['Memory']=fdf['Memory'].apply(lambda x: float(x.split()[0]) / 1024 if 'MB' in x else (float(x.split()[0]) if x.isnumeric() else float(x[:-2])))

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2436 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2436 non-null   object
#  1   Model           2436 non-null   object
#  2   Color           2436 non-null   object
#  3   Memory          2436 non-null   float64
#  4   Storage         2436 non-null   object
#  5   Rating          2436 non-null   float64
#  6   Selling Price   2436 non-null   int32
#  7   Original Price  2436 non-null   int32
# dtypes: float64(2), int32(2), object(4)
# memory usage: 152.2+ KB

# %%
fdf.describe
# Out:
# <bound method NDFrame.describe of        Brand      Model            Color  Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black     4.0   64 GB     4.5
# 1       OPPO        A53       Mint Cream     4.0   64 GB     4.5
# 2       OPPO        A53  Moonlight Black     6.0  128 GB     4.3
# 3       OPPO        A53       Mint Cream     6.0  128 GB     4.3
# 4       OPPO        A53   Electric Black     4.0   64 GB     4.5
# ...      ...        ...              ...     ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red     4.0   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue     3.0   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue     4.0   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black     3.0   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black     4.0   64 GB     4.3
#
#       Selling Price  Original Price
# 0             11990           15990
# 1             11990           15990
# 2             13990           17990
# ...

# %%
fdf.describe()
# Out:
#             Memory       Rating  Selling Price  Original Price
# count  2436.000000  2436.000000    2436.000000     2436.000000
# mean      4.126179     4.039532   27297.366174    29382.552956
# std       2.308587     0.935027   29143.243048    30922.295767
# min       0.062500     0.000000    2290.000000     2290.000000
# 25%       3.000000     4.000000    9999.000000    10999.000000
# 50%       4.000000     4.300000   15990.000000    16999.000000
# 75%       6.000000     4.400000   30922.500000    34900.000000
# max      18.000000     5.000000  179900.000000   189999.000000

# %% [markdown]
# cheapestPhone=fdf.sort_values(['Selling Price', 'Memory']).iloc[0]
# cheapestPhone

# %%
cheapestPhone=fdf.sort_values(['Selling Price', 'Memory']).iloc[0] 
cheapestPhone
# Out:
# Brand                  GIONEE
# Model             Pioneer P2
# Color                   Black
# Memory                    0.5
# Storage                  4 GB
# Rating                    3.6
# Selling Price            2290
# Original Price           2290
# Name: 902, dtype: object

# %% [markdown]
# #Removing the data with the ram less tham 1 gb

# %%
fdf = fdf[fdf['Memory'] >= 1]

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2389 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2389 non-null   object
#  1   Model           2389 non-null   object
#  2   Color           2389 non-null   object
#  3   Memory          2389 non-null   float64
#  4   Storage         2389 non-null   object
#  5   Rating          2389 non-null   float64
#  6   Selling Price   2389 non-null   int32
#  7   Original Price  2389 non-null   int32
# dtypes: float64(2), int32(2), object(4)
# memory usage: 149.3+ KB

# %%
filtered_df = fdf[(fdf['Memory'] > 1) & (fdf['Memory'] < 2)]
costliest_phone = filtered_df.sort_values('Selling Price', ascending=False).iloc[0]
costliest_phone
# Out:
# Brand                      SAMSUNG
# Model             Galaxy Mega 5.8
# Color                        Black
# Memory                         1.5
# Storage                       8 GB
# Rating                         3.8
# Selling Price                26000
# Original Price               26000
# Name: 2139, dtype: object

# %%
cheapest_phone = filtered_df.sort_values('Selling Price').iloc[0]
cheapest_phone
# Out:
# Brand                LG
# Model              K-7
# Color             Titan
# Memory              1.5
# Storage            8 GB
# Rating              4.1
# Selling Price      6590
# Original Price     6590
# Name: 347, dtype: object

# %%
fdf = fdf[fdf['Memory'] >= 2]

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2187 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2187 non-null   object
#  1   Model           2187 non-null   object
#  2   Color           2187 non-null   object
#  3   Memory          2187 non-null   float64
#  4   Storage         2187 non-null   object
#  5   Rating          2187 non-null   float64
#  6   Selling Price   2187 non-null   int32
#  7   Original Price  2187 non-null   int32
# dtypes: float64(2), int32(2), object(4)
# memory usage: 136.7+ KB

# %%
filtered_df2to3 = fdf[(fdf['Memory'] > 2) & (fdf['Memory'] <= 3)]
x=len(filtered_df2to3)
x
# Out:
# 435

# %%
cheap2to3 = filtered_df2to3.sort_values('Selling Price').iloc[0]

cheap2to3
#from this found that there is no phone in between them
# Out:
# Brand                GIONEE
# Model             F103 Pro
# Color                  Gold
# Memory                  3.0
# Storage               16 GB
# Rating                  3.9
# Selling Price          5290
# Original Price         5290
# Name: 822, dtype: object

# %%
costliest2to3 = filtered_df2to3.sort_values('Selling Price',ascending=False).iloc[0]

costliest2to3
# Out:
# Brand                 Apple
# Model             iPhone X
# Color                Silver
# Memory                  3.0
# Storage              256 GB
# Rating                  4.6
# Selling Price        106900
# Original Price       106900
# Name: 1475, dtype: object

# %%
fdf=fdf[fdf['Memory']>=4]

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           1413 non-null   object
#  1   Model           1413 non-null   object
#  2   Color           1413 non-null   object
#  3   Memory          1413 non-null   float64
#  4   Storage         1413 non-null   object
#  5   Rating          1413 non-null   float64
#  6   Selling Price   1413 non-null   int32
#  7   Original Price  1413 non-null   int32
# dtypes: float64(2), int32(2), object(4)
# memory usage: 88.3+ KB

# %%
fdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           1413 non-null   object
#  1   Model           1413 non-null   object
#  2   Color           1413 non-null   object
#  3   Memory          1413 non-null   float64
#  4   Storage         1413 non-null   int64
#  5   Rating          1413 non-null   float64
#  6   Selling Price   1413 non-null   int32
#  7   Original Price  1413 non-null   int32
# dtypes: float64(2), int32(2), int64(1), object(3)
# memory usage: 88.3+ KB

# %%
fdf.describe()
# Out:
#             Memory      Storage       Rating  Selling Price  Original Price
# count  1413.000000  1413.000000  1413.000000    1413.000000     1413.000000
# mean      5.541401   132.914367     4.038641   34567.978061    37692.048125
# std       1.981291   120.871395     1.089114   33236.642338    35309.475062
# min       4.000000    32.000000     0.000000    6399.000000     6399.000000
# 25%       4.000000    64.000000     4.200000   14443.000000    15499.000000
# 50%       4.000000   128.000000     4.300000   19990.000000    21990.000000
# 75%       6.000000   128.000000     4.400000   39999.000000    44999.000000
# max      18.000000  1024.000000     4.700000  179900.000000   189999.000000

# %%
x=sea.countplot(data=fdf,x='Memory')
for bars in x.containers:
    x.bar_label(bars)

# %%
sea.countplot(data=fdf,x='Storage')
# Out:
# <AxesSubplot:xlabel='Storage', ylabel='count'>

# %%
sea.countplot(data=fdf,x='Rating')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %%
x=sea.countplot(data=fdf,x='Storage',hue='Memory')
for bars in x.containers:
    x.bar_label(bars)

# %%
fdf.columns
# Out:
# Index(['Brand', 'Model', 'Color', 'Memory', 'Storage', 'Rating',
#        'Selling Price', 'Original Price'],
#       dtype='object')

# %%
sea.countplot(data=fdf,x='Brand')
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='count'>

# %% [markdown]
# #which company phones are high code

# %%
sea.countplot(x='Selling Price',data=fdf,hue='Brand')
# Out:
# <AxesSubplot:xlabel='Selling Price', ylabel='count'>

# %%
x=fdf.sort_values(by='Selling Price', ascending=False)
top_10_phones = x.groupby('Brand').head(10)
sea.barplot(data=top_10_phones, x='Brand', y='Selling Price')
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='Selling Price'>

# %% [markdown]
# # Number of phone sold with 4 gb 64 storage,4 gb 128 storage,6 gb 64 storage,6 gb 128 storage

# %%
fdf.describe()
# Out:
#             Memory      Storage       Rating  Selling Price  Original Price
# count  2436.000000  2436.000000  2436.000000    2436.000000     2436.000000
# mean     13.305829    88.949507     4.039532   27297.366174    29382.552956
# std      70.889326    92.489344     0.935027   29143.243048    30922.295767
# min       0.000000     1.000000     0.000000    2290.000000     2290.000000
# 25%       3.000000    32.000000     4.000000    9999.000000    10999.000000
# 50%       4.000000    64.000000     4.300000   15990.000000    16999.000000
# 75%       6.000000   128.000000     4.400000   30922.500000    34900.000000
# max     768.000000   512.000000     5.000000  179900.000000   189999.000000

# %%
filtered_phones = fdf[(fdf['Memory'] == 4) & (fdf['Storage'] == 64) & (fdf['Rating'] > 4)]
len(filtered_phones)
# Out:
# 397

# %%
filtered_phones = fdf[(fdf['Memory'] == 4) & (fdf['Storage'] == 64) & (fdf['Rating'] > 3)]
len(filtered_phones)
filtered_phones.sort_values(['Selling Price'],ascending=False).iloc[0]
filtered_phones.sort_values(['Selling Price']).iloc[0]
# Out:
# Brand             GIONEE
# Model                A1
# Color               Gold
# Memory               4.0
# Storage               64
# Rating               4.0
# Selling Price       7675
# Original Price      8999
# Name: 865, dtype: object

# %%
fdf.sort_values(['Selling Price'],ascending=False).iloc[0]
# Out:
# Brand                          Apple
# Model             iPhone 13 Pro Max
# Color                       Graphite
# Memory                           6.0
# Storage                         1024
# Rating                           0.0
# Selling Price                 179900
# Original Price                179900
# Name: 1415, dtype: object

# %%
costliest_phones=costliest_phones.drop('Color',axis=1)
costliest_phones = fdf.groupby('Brand').apply(lambda x: x[x['Selling Price'] == x['Selling Price'].max()])
costliest_phones = costliest_phones.reset_index(drop=True, level=0)
costliest_phones
# Out:
#              Brand                  Model              Color  Memory  Storage  \
# 477           ASUS  ROG Phone 5 Ultimate               White    18.0      512
# 1234         Apple     iPhone 13 Pro Max         Sierra Blue     6.0     1024
# 1352         Apple     iPhone 13 Pro Max                Gold     6.0     1024
# 1415         Apple     iPhone 13 Pro Max            Graphite     6.0     1024
# 1460         Apple     iPhone 13 Pro Max              Silver     6.0     1024
# 789         GIONEE                    A1                Grey     4.0       64
# 263   Google Pixel                  3 XL       Clearly White     4.0      128
# 266   Google Pixel                  3 XL          Just Black     4.0      128
# 272   Google Pixel                  3 XL            Not Pink     4.0      128
# 244            HTC                  U11+      Amazing Silver     6.0      128
# 253           IQOO                      3      Tornado Black    12.0      256
# ...

# %%
fdf['bestDiscount']=fdf['Original Price']-fdf['Selling Price']
x=fdf.sort_values(by='bestDiscount',ascending=False).iloc[0]
x
# Out:
# Brand             Motorola
# Model                Razr
# Color                Black
# Memory                 6.0
# Storage                128
# Rating                 3.8
# Selling Price        74999
# Original Price      149999
# bestDiscount         75000
# Name: 2319, dtype: object

# %%
sea.pairplot(fdf, hue='Brand')

# %%
sea.displot(fdf, x='Selling Price', hue='Brand')

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax=sea.countplot(x="Brand", data=fdf)
